# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import keras
import tensorflow
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Sequential
from tensorflow.keras import datasets,layers,models
from sklearn.metrics import roc_curve, auc
import cv2
from tqdm import tqdm
import tensorflow as tf

# %%
churn_data = pd.read_csv('Churn_Modelling.csv',index_col='RowNumber')

# %%
churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
churn_data.describe()
# Out:
#          CustomerId   CreditScore           Age        Tenure        Balance  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000   10000.000000
# mean   1.569094e+07    650.528800     38.921800      5.012800   76485.889288
# std    7.193619e+04     96.653299     10.487806      2.892174   62397.405202
# min    1.556570e+07    350.000000     18.000000      0.000000       0.000000
# 25%    1.562853e+07    584.000000     32.000000      3.000000       0.000000
# 50%    1.569074e+07    652.000000     37.000000      5.000000   97198.540000
# 75%    1.575323e+07    718.000000     44.000000      7.000000  127644.240000
# max    1.581569e+07    850.000000     92.000000     10.000000  250898.090000
#
#        NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary  \
# count   10000.000000  10000.00000    10000.000000     10000.000000
# mean        1.530200      0.70550        0.515100    100090.239881
# std         0.581654      0.45584        0.499797     57510.492818
# min         1.000000      0.00000        0.000000        11.580000
# 25%         1.000000      0.00000        0.000000     51002.110000
# 50%         1.000000      1.00000        1.000000    100193.915000
# 75%         2.000000      1.00000        1.000000    149388.247500
# max         4.000000      1.00000        1.000000    199992.480000
#
#              Exited
# count  10000.000000
# mean       0.203700
# std        0.402769
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
churn_data.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# 2                112542.58       0
# 3                113931.57       1
# 4                 93826.63       0
# 5                 79084.10       0

# %%
churn_data.drop(['CustomerId','Surname'],axis=1,inplace=True)

# %%
churn_data.head()
# Out:
#            CreditScore Geography  Gender  Age  Tenure    Balance  \
# RowNumber
# 1                  619    France  Female   42       2       0.00
# 2                  608     Spain  Female   41       1   83807.86
# 3                  502    France  Female   42       8  159660.80
# 4                  699    France  Female   39       1       0.00
# 5                  850     Spain  Female   43       2  125510.82
#
#            NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# RowNumber
# 1                      1          1               1        101348.88       1
# 2                      1          0               1        112542.58       0
# 3                      3          1               0        113931.57       1
# 4                      2          0               0         93826.63       0
# 5                      1          1               1         79084.10       0

# %%
Geography_dummies = pd.get_dummies(prefix='Geo',data=churn_data,columns=['Geography'])

# %%
Geography_dummies.head()
# Out:
#            CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  \
# RowNumber
# 1                  619  Female   42       2       0.00              1
# 2                  608  Female   41       1   83807.86              1
# 3                  502  Female   42       8  159660.80              3
# 4                  699  Female   39       1       0.00              2
# 5                  850  Female   43       2  125510.82              1
#
#            HasCrCard  IsActiveMember  EstimatedSalary  Exited  Geo_France  \
# RowNumber
# 1                  1               1        101348.88       1           1
# 2                  0               1        112542.58       0           0
# 3                  1               0        113931.57       1           1
# 4                  0               0         93826.63       0           1
# 5                  1               1         79084.10       0           0
#
#            Geo_Germany  Geo_Spain
# RowNumber
# 1                    0          0
# 2                    0          1
# 3                    0          0
# 4                    0          0
# 5                    0          1

# %%
Gender_dummies = Geography_dummies.replace(to_replace={'Gender': {'Female': 1,'Male':0}})

# %%
Gender_dummies.head()
# Out:
#            CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  \
# RowNumber
# 1                  619       1   42       2       0.00              1
# 2                  608       1   41       1   83807.86              1
# 3                  502       1   42       8  159660.80              3
# 4                  699       1   39       1       0.00              2
# 5                  850       1   43       2  125510.82              1
#
#            HasCrCard  IsActiveMember  EstimatedSalary  Exited  Geo_France  \
# RowNumber
# 1                  1               1        101348.88       1           1
# 2                  0               1        112542.58       0           0
# 3                  1               0        113931.57       1           1
# 4                  0               0         93826.63       0           1
# 5                  1               1         79084.10       0           0
#
#            Geo_Germany  Geo_Spain
# RowNumber
# 1                    0          0
# 2                    0          1
# 3                    0          0
# 4                    0          0
# 5                    0          1

# %%
churn_data.head()
# Out:
#            CreditScore Geography  Gender  Age  Tenure    Balance  \
# RowNumber
# 1                  619    France  Female   42       2       0.00
# 2                  608     Spain  Female   41       1   83807.86
# 3                  502    France  Female   42       8  159660.80
# 4                  699    France  Female   39       1       0.00
# 5                  850     Spain  Female   43       2  125510.82
#
#            NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# RowNumber
# 1                      1          1               1        101348.88       1
# 2                      1          0               1        112542.58       0
# 3                      3          1               0        113931.57       1
# 4                      2          0               0         93826.63       0
# 5                      1          1               1         79084.10       0

# %%
churn_data_encoded = Gender_dummies

# %%
X = churn_data_encoded.drop(['Exited'],axis=1)
y = churn_data_encoded.Exited

# %%
X.head(10)
# Out:
#            CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  \
# RowNumber
# 1                  619       1   42       2       0.00              1
# 2                  608       1   41       1   83807.86              1
# 3                  502       1   42       8  159660.80              3
# 4                  699       1   39       1       0.00              2
# 5                  850       1   43       2  125510.82              1
# 6                  645       0   44       8  113755.78              2
# 7                  822       0   50       7       0.00              2
# 8                  376       1   29       4  115046.74              4
# 9                  501       0   44       4  142051.07              2
# 10                 684       0   27       2  134603.88              1
#
#            HasCrCard  IsActiveMember  EstimatedSalary  Geo_France  \
# RowNumber
# 1                  1               1        101348.88           1
# 2                  0               1        112542.58           0
# 3                  1               0        113931.57           1
# 4                  0               0         93826.63           1
# 5                  1               1         79084.10           0
# 6                  1               0        149756.71           0
# 7                  1               1         10062.80           1
# 8                  1               0        119346.88           0
# 9                  0               1         74940.50           1
# 10                 1               1         71725.73           1
#
#            Geo_Germany  Geo_Spain
# RowNumber
# 1                    0          0
# 2                    0          1
# 3                    0          0
# 4                    0          0
# 5                    0          1
# 6                    0          1
# 7                    0          0
# 8                    1          0
# 9                    0          0
# 10                   0          0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.svm import SVC
rbf = SVC(kernel='rbf', gamma=0.5, C=0.1).fit(X_train, y_train)
poly = SVC(kernel='poly', degree=3, C=1).fit(X_train, y_train)
linear = SVC(kernel='linear', probability=True, random_state=42)
history=linear.fit(X_train, y_train)
RF = SVC(decision_function_shape='ovo') 
RF.fit(X_train, y_train)
# Out:
# SVC(decision_function_shape='ovo')

# %%
rf_pred = RF.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
rf_accuracy = accuracy_score(y_test, rf_pred)

# %%
print(rf_accuracy)
# Out:
# 0.8569696969696969

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,  rf_pred)
p = sns.heatmap(pd.DataFrame(cm), annot=True, cmap="YlGnBu" ,fmt='g')
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 15.0, 'Predicted label')

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)
print(len(X_test))
print(len(X_train))
print("Start training..\n")

model = Sequential()


model.add(layers.Dropout(0.1))

model.add(layers.Flatten())  # this converts our 3D feature(width,height,channel) maps to 1D feature vectors

model.add(layers.Dense(64,activation='relu'))#feature selection

model.add(layers.Dense(5))#activition = "softmax"


model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])#combination between two GD methodologies "adam"


history = model.fit(X_train, y_train,epochs=15, validation_data=(X_test, y_test))
test_loss, test_acc = model.evaluate(X_test,  y_test, verbose=2)
print("accuracy ",test_acc)#99

#model.save("ann.model")#99


print("End training..\n")
print(history.history)
# Out:
# 3300
# 6700
# Start training..
#
# Epoch 1/15
# 210/210 [==============================] - 1s 4ms/step - loss: 0.7571 - accuracy: 0.7276 - val_loss: 0.4658 - val_accuracy: 0.8170
# Epoch 2/15
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4398 - accuracy: 0.8193 - val_loss: 0.4126 - val_accuracy: 0.8309
# Epoch 3/15
# 210/210 [==============================] - 1s 3ms/step - loss: 0.4078 - accuracy: 0.8293 - val_loss: 0.3876 - val_accuracy: 0.8467
# Epoch 4/15
# 210/210 [==============================] - 1s 4ms/step - loss: 0.3917 - accuracy: 0.8349 - val_loss: 0.3733 - val_accuracy: 0.8500
# Epoch 5/15
# 210/210 [==============================] - 1s 4ms/step - loss: 0.3834 - accuracy: 0.8413 - val_loss: 0.3674 - val_accuracy: 0.8527
# Epoch 6/15
# 210/210 [==============================] - 1s 4ms/step - loss: 0.3790 - accuracy: 0.8452 - val_loss: 0.3602 - val_accuracy: 0.8545
# Epoch 7/15
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3747 - accuracy: 0.8457 - val_loss: 0.3604 - val_accuracy: 0.8527
# Epoch 8/15
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3691 - accuracy: 0.8461 - val_loss: 0.3576 - val_accuracy: 0.8585
# Epoch 9/15
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3662 - accuracy: 0.8499 - val_loss: 0.3566 - val_accuracy: 0.8533
# Epoch 10/15
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3685 - accuracy: 0.8499 - val_loss: 0.3527 - val_accuracy: 0.8548
# Epoch 11/15
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3648 - accuracy: 0.8527 - val_loss: 0.3525 - val_accuracy: 0.8561
# Epoch 12/15
# 210/210 [==============================] - 1s 4ms/step - loss: 0.3682 - accuracy: 0.8457 - val_loss: 0.3524 - val_accuracy: 0.8570
# Epoch 13/15
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3652 - accuracy: 0.8501 - val_loss: 0.3520 - val_accuracy: 0.8582
# Epoch 14/15
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3662 - accuracy: 0.8467 - val_loss: 0.3541 - val_accuracy: 0.8524
# Epoch 15/15
# 210/210 [==============================] - 1s 3ms/step - loss: 0.3630 - accuracy: 0.8510 - val_loss: 0.3512 - val_accuracy: 0.8582
# 104/104 - 0s - loss: 0.3512 - accuracy: 0.8582 - 185ms/epoch - 2ms/step
# accuracy  0.8581818342208862
# End training..
#
# {'loss': [0.757111132144928, 0.4397905468940735, 0.40778443217277527, 0.39165300130844116, 0.3834373950958252, 0.3790390193462372, 0.3746945559978485, 0.3691216707229614, 0.36621180176734924, 0.36854538321495056, 0.36479341983795166, 0.368193656206131, 0.3652294874191284, 0.36620572209358215, 0.36303630471229553], 'accuracy': [0.7276119589805603, 0.8192537426948547, 0.8292537331581116, 0.8349253535270691, 0.8413432836532593, 0.8452239036560059, 0.8456716537475586, 0.8461194038391113, 0.8498507738113403, 0.8498507738113403, 0.8526865839958191, 0.8456716537475586, 0.8501492738723755, 0.8467164039611816, 0.851044774055481], 'val_loss': [0.465824156999588, 0.41260993480682373, 0.3876376748085022, 0.37326863408088684, 0.36739712953567505, 0.36015936732292175, 0.3604348301887512, 0.3576402962207794, 0.35657668113708496, 0.352706640958786, 0.3524637222290039, 0.35236838459968567, 0.35203835368156433, 0.3540519177913666, 0.3512340486049652], 'val_accuracy': [0.8169696927070618, 0.8309090733528137, 0.846666693687439, 0.8500000238418579, 0.8527272939682007, 0.8545454740524292, 0.8527272939682007, 0.8584848642349243, 0.8533333539962769, 0.8548485040664673, 0.8560606241226196, 0.8569697141647339, 0.8581818342208862, 0.8524242639541626, 0.8581818342208862]}

# %%
loss_train = history.history['loss']
epochs = range(1,16)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
plt.savefig("loss.png")

# %%
loss_train = history.history['accuracy']
epochs = range(1,16)
plt.plot(epochs, loss_train, 'g', label='Training accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
